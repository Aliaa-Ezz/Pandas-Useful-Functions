# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = {'Name': ['Aliaa', 'Toqa', 'Rawan', 'Randa', 'Israa', 'Aya'], 'Averages':[25,70, 55, 98, 36, 77]}
df = pd.DataFrame(data)
df
# Out:
#     Name  Averages
# 0  Aliaa        25
# 1   Toqa        70
# 2  Rawan        55
# 3  Randa        98
# 4  Israa        36
# 5    Aya        77

# %%
fig = plt.figure(figsize=(15,12))
ax = fig.add_subplot(111, projection="polar")
plt.title('Averages')
# theta has 6 different angles, and the first one repeated
theta = np.arange(len(df) + 1) / float(len(df)) * 2* np.pi
# values has the 6 values from 'Col B', with the first element repeated
values = df['Averages'].values
values = np.append(values, values[0])

# draw the polygon and the mark the points for each angle/value combination
l1, = ax.plot(theta, values,color="C2", marker="o", label="Name of index")
plt.xticks(theta[:-1], df['Name'], color='grey', size=12)
ax.tick_params(pad=10) # to increase the distance of the labels to the plot
# fill the area of the polygon with green and some transparency
ax.fill(theta, values, 'green', alpha=0.1)

#plt.legend() # shows the legend, using the label of the line plot (useful when there is more than 1 polygon)

plt.savefig('Totals/' + 'Radar' + '.png' , bbox_inches="tight")
